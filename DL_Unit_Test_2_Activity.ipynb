# %%
### Name: Sonali Surpatne
### Roll no: BECOD455
### Div: D
### Topic: Image Segmentation using CNN For Breast Cancer Dataset

# %%
import tensorflow as tf
import pandas as pd 
from PIL import Image
import os
import numpy as np
import matplotlib.pyplot as plt 
import os 
import pathlib 
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Import the libraries
import zipfile
import os

zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset/archive (3).zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()

# %%
path = '/tmp/Dataset_BUSI_with_GT'
data_dir = pathlib.Path(path)

# %%
class_names = np.array(sorted([item.name for item in data_dir.glob("*")]))
class_names
# Out:
# array(['benign', 'malignant', 'normal'], dtype='<U9')

# %%
benignPath = os.path.join(data_dir,'bening')
malignantPath = os.path.join(data_dir,'malignant')
normalPath = os.path.join(data_dir,'normal')

# %%
imageCount = len(list(data_dir.glob('*/*.png')))
imageCount
# Out:
# 1578

# %%
plt.figure(figsize=(15,15))

for i in range(25):
    plt.subplot(5,5,i+1)
    random_class = random.choice(class_names)
    img = plt.imread(random.choice(list(data_dir.glob(random_class+"/*.png"))))
    plt.xticks([])
    plt.yticks([])
    plt.title(random_class)
    plt.imshow(img)

# %%
from pathlib import Path
import imghdr

data_dir = '/tmp/Dataset_BUSI_with_GT'
image_extensions = [".png", ".jpg"]  # add there all your images file extensions

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(f"{filepath} is not an image")
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_data = image_dataset_from_directory(
                  data_dir,
                  validation_split=0.2,
                  subset="training",
                  seed=123,
                  image_size=(img_height, img_width),
                  batch_size=batch_size)


val_data = image_dataset_from_directory(data_dir,
                                        validation_split=0.2,
                                        subset="validation",
                                        seed=123,
                                        image_size=(img_height,img_width),
                                        batch_size=batch_size)
# Out:
# Found 1578 files belonging to 3 classes.
# Using 1263 files for training.
# Found 1578 files belonging to 3 classes.
# Using 315 files for validation.

# %%
from tensorflow.keras import layers 
model = tf.keras.Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
    
  layers.Dropout(0.5),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(3,activation="softmax")
])

# %%
model.compile(optimizer="Adam",
            loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
            metrics=["accuracy"])

# %%
epochs = 25
history = model.fit(train_data,
                    epochs=epochs,
                    validation_data=val_data, 
                    batch_size=batch_size)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.9/dist-packages/keras/backend.py:5612: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 40/40 [==============================] - 19s 184ms/step - loss: 0.9096 - accuracy: 0.5780 - val_loss: 0.7508 - val_accuracy: 0.6825
# Epoch 2/25
# 40/40 [==============================] - 7s 149ms/step - loss: 0.6709 - accuracy: 0.7086 - val_loss: 0.7609 - val_accuracy: 0.6571
# Epoch 3/25
# 40/40 [==============================] - 8s 174ms/step - loss: 0.5566 - accuracy: 0.7585 - val_loss: 0.7416 - val_accuracy: 0.7143
# Epoch 4/25
# 40/40 [==============================] - 6s 132ms/step - loss: 0.4215 - accuracy: 0.8242 - val_loss: 0.8180 - val_accuracy: 0.7175
# Epoch 5/25
# 40/40 [==============================] - 8s 179ms/step - loss: 0.3162 - accuracy: 0.8725 - val_loss: 0.8207 - val_accuracy: 0.7746
# Epoch 6/25
# 40/40 [==============================] - 6s 132ms/step - loss: 0.2438 - accuracy: 0.9113 - val_loss: 1.0360 - val_accuracy: 0.7302
# Epoch 7/25
# 40/40 [==============================] - 8s 174ms/step - loss: 0.1936 - accuracy: 0.9319 - val_loss: 1.1123 - val_accuracy: 0.7746
# Epoch 8/25
# 40/40 [==============================] - 6s 132ms/step - loss: 0.1383 - accuracy: 0.9517 - val_loss: 1.1246 - val_accuracy: 0.7683
# Epoch 9/25
# 40/40 [==============================] - 8s 175ms/step - loss: 0.1006 - accuracy: 0.9683 - val_loss: 1.2322 - val_accuracy: 0.7778
# Epoch 10/25
# 40/40 [==============================] - 6s 136ms/step - loss: 0.0832 - accuracy: 0.9770 - val_loss: 1.2460 - val_accuracy: 0.7460
# Epoch 11/25
# 40/40 [==============================] - 6s 133ms/step - loss: 0.0662 - accuracy: 0.9826 - val_loss: 1.5062 - val_accuracy: 0.7905
# Epoch 12/25
# 40/40 [==============================] - 6s 133ms/step - loss: 0.0553 - accuracy: 0.9818 - val_loss: 1.3554 - val_accuracy: 0.7778
# Epoch 13/25
# 40/40 [==============================] - 8s 171ms/step - loss: 0.0504 - accuracy: 0.9873 - val_loss: 1.6236 - val_accuracy: 0.7746
# Epoch 14/25
# 40/40 [==============================] - 6s 131ms/step - loss: 0.0552 - accuracy: 0.9873 - val_loss: 1.4809 - val_accuracy: 0.7524
# Epoch 15/25
# 40/40 [==============================] - 8s 175ms/step - loss: 0.0491 - accuracy: 0.9921 - val_loss: 1.3521 - val_accuracy: 0.7714
# Epoch 16/25
# 40/40 [==============================] - 8s 169ms/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 1.3443 - val_accuracy: 0.8000
# Epoch 17/25
# 40/40 [==============================] - 6s 134ms/step - loss: 0.0118 - accuracy: 0.9968 - val_loss: 1.4939 - val_accuracy: 0.7841
# Epoch 18/25
# 40/40 [==============================] - 9s 217ms/step - loss: 0.0131 - accuracy: 0.9952 - val_loss: 1.4936 - val_accuracy: 0.7873
# Epoch 19/25
# 40/40 [==============================] - 6s 132ms/step - loss: 0.0076 - accuracy: 0.9968 - val_loss: 1.5356 - val_accuracy: 0.7778
# Epoch 20/25
# 40/40 [==============================] - 8s 173ms/step - loss: 0.0085 - accuracy: 0.9960 - val_loss: 1.6941 - val_accuracy: 0.7810
# Epoch 21/25
# 40/40 [==============================] - 6s 131ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 1.6565 - val_accuracy: 0.7587
# Epoch 22/25
# 40/40 [==============================] - 6s 133ms/step - loss: 0.0113 - accuracy: 0.9952 - val_loss: 1.5903 - val_accuracy: 0.7873
# Epoch 23/25
# 40/40 [==============================] - 8s 148ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 1.6797 - val_accuracy: 0.7746
# Epoch 24/25
# 40/40 [==============================] - 6s 136ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 1.6261 - val_accuracy: 0.7937
# Epoch 25/25
# 40/40 [==============================] - 8s 148ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 1.7722 - val_accuracy: 0.7905

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc =  history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Accuracy')
plt.plot(epochs_range,val_acc,label="Validation Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Loss')
plt.plot(epochs_range,val_loss,label="Validation Loss")
plt.legend()
plt.show()

# %%
model.evaluate(val_data)
# Out:
# 10/10 [==============================] - 1s 29ms/step - loss: 1.7722 - accuracy: 0.7905
# [1.7722303867340088, 0.7904762029647827]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 28, 28, 64)        0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 128)               6422656
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 6,446,627
# Trainable params: 6,446,627
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=(15, 15))
class_names = val_data.class_names
result = ' | False'
for images, labels in val_data.take(1):
    for i in range(25):
        
        ax = plt.subplot(5, 5, i + 1)
        img = images[i].numpy().astype("uint8")
        img = tf.expand_dims(img, axis=0)
        
        predictions = model.predict(img)
        predicted_class = np.argmax(predictions)
        if class_names[predicted_class] == class_names[labels[i]]:
            result = ' | TRUE'
            
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[predicted_class]+result  )
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 207ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step

# %%
###  Github Link:
